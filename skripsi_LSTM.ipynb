# %%
# %pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (3.9.4)
# Requirement already satisfied: seaborn in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (2.6.0+cu126)
# Requirement already satisfied: torchvision in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (0.21.0+cu126)
# Requirement already satisfied: torchaudio in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (2.6.0+cu126)
# Requirement already satisfied: filelock in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 2060

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device: ', device)
# Out:
# Using device:  cuda

# %%
# %pip install --no-cache-dir numpy==1.23.5 scipy scikit-learn==1.3.0 scikeras tensorflow keras
# Out:
# Requirement already satisfied: numpy==1.23.5 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (1.23.5)
# Requirement already satisfied: scipy in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (1.13.1)
# Collecting scikit-learn==1.3.0
#   Downloading scikit_learn-1.3.0-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scikeras in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (0.12.0)
# Requirement already satisfied: tensorflow in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (2.17.1)
# Requirement already satisfied: keras in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (3.9.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.3.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.3.0) (3.5.0)
# Requirement already satisfied: packaging>=0.21 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from scikeras) (24.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem<0.32,>=0.23.1 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from scikeras) (0.31.0)
# Requirement already satisfied: tensorflow-intel==2.17.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.17.1)
# Requirement already satisfied: rich in c:\users\aledh\appdata\roaming\python\python39\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\aledh\appdata\roaming\python\python39\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\aledh\appdata\roaming\python\python39\site-packages (from keras) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (8.6.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\aledh\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (3.21.0)
# Downloading scikit_learn-1.3.0-cp39-cp39-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    -- ------------------------------------- 0.5/9.3 MB 101.1 kB/s eta 0:01:28
#    --- ------------------------------------ 0.8/9.3 MB 121.1 kB/s eta 0:01:11
#    --- ------------------------------------ 0.8/9.3 MB 121.1 kB/s eta 0:01:11
#    --- ------------------------------------ 0.8/9.3 MB 121.1 kB/s eta 0:01:11
#    ---- ----------------------------------- 1.0/9.3 MB 159.8 kB/s eta 0:00:52
#    ---- ----------------------------------- 1.0/9.3 MB 159.8 kB/s eta 0:00:52
#    ---- ----------------------------------- 1.0/9.3 MB 159.8 kB/s eta 0:00:52
#    ---- ----------------------------------- 1.0/9.3 MB 159.8 kB/s eta 0:00:52
#    ----- ---------------------------------- 1.3/9.3 MB 182.4 kB/s eta 0:00:44
#    ----- ---------------------------------- 1.3/9.3 MB 182.4 kB/s eta 0:00:44
#    ------ --------------------------------- 1.6/9.3 MB 208.6 kB/s eta 0:00:38
#    ------ --------------------------------- 1.6/9.3 MB 208.6 kB/s eta 0:00:38
#    ------- -------------------------------- 1.8/9.3 MB 234.6 kB/s eta 0:00:32
#    ------- -------------------------------- 1.8/9.3 MB 234.6 kB/s eta 0:00:32
#    --------- ------------------------------ 2.1/9.3 MB 259.2 kB/s eta 0:00:28
#    ---------- ----------------------------- 2.4/9.3 MB 285.6 kB/s eta 0:00:25
#    ----------- ---------------------------- 2.6/9.3 MB 313.9 kB/s eta 0:00:22
#    ----------- ---------------------------- 2.6/9.3 MB 313.9 kB/s eta 0:00:22
#    ----------- ---------------------------- 2.6/9.3 MB 313.9 kB/s eta 0:00:22
#    ------------ --------------------------- 2.9/9.3 MB 326.4 kB/s eta 0:00:20
#    ------------ --------------------------- 2.9/9.3 MB 326.4 kB/s eta 0:00:20
#    ------------- -------------------------- 3.1/9.3 MB 343.7 kB/s eta 0:00:18
#    ------------- -------------------------- 3.1/9.3 MB 343.7 kB/s eta 0:00:18
#    -------------- ------------------------- 3.4/9.3 MB 356.9 kB/s eta 0:00:17
#    -------------- ------------------------- 3.4/9.3 MB 356.9 kB/s eta 0:00:17
#    --------------- ------------------------ 3.7/9.3 MB 364.1 kB/s eta 0:00:16
#    --------------- ------------------------ 3.7/9
6 kB/s eta 0:00:09
#    ----------------------------- ---------- 6.8/9.3 MB 299.6 kB/s eta 0:00:09
#    ------------------------------ --------- 7.1/9.3 MB 300.8 kB/s eta 0:00:08
#    ------------------------------ --------- 7.1/9.3 MB 300.8 kB/s eta 0:00:08
#    ------------------------------ --------- 7.1/9.3 MB 300.8 kB/s eta 0:00:08
#    ------------------------------ --------- 7.1/9.3 MB 300.8 kB/s eta 0:00:08
#    ------------------------------- -------- 7.3/9.3 MB 299.6 kB/s eta 0:00:07
#    ------------------------------- -------- 7.3/9.3 MB 299.6 kB/s eta 0:00:07
#    ------------------------------- -------- 7.3/9.3 MB 299.6 kB/s eta 0:00:07
#    -------------------------------- ------- 7.6/9.3 MB 302.9 kB/s eta 0:00:06
#    --------------------------------- ------ 7.9/9.3 MB 310.3 kB/s eta 0:00:05
#    ---------------------------------- ----- 8.1/9.3 MB 318.3 kB/s eta 0:00:04
#    ------------------------------------ --- 8.4/9.3 MB 326.7 kB/s eta 0:00:03
#    ------------------------------------- -- 8.7/9.3 MB 335.3 kB/s eta 0:00:02
#    ---------------------------------------  9.2/9.3 MB 351.9 kB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 356.6 kB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn==1.2.2
# Out:
# Collecting scikit-learn==1.2.2
#   Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.2.2) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.2.2) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aledh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn==1.2.2) (3.5.0)
# Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed scikit-learn-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
file_path = '../skripsi/dataset_mandiri_20tahun.csv'
df = pd.read_csv(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4937 non-null   object
#  1   Open       4937 non-null   object
#  2   High       4937 non-null   object
#  3   Low        4937 non-null   object
#  4   Close      4937 non-null   object
#  5   Adj Close  4937 non-null   object
#  6   Volume     4937 non-null   object
# dtypes: object(7)
# memory usage: 270.1+ KB

# %%
df.describe()
# Out:
#                 Date      Open      High       Low     Close Adj Close Volume
# count           4937      4937      4937      4937      4937      4937   4937
# unique          4937       738       754       762       766      1669   4810
# top     Dec 30, 2024  3,500.00  1,762.50  3,475.00  3,587.50  1,078.23      -
# freq               1        26        26        30        30        17    105

# %%
df.isnull().sum()/len(df)
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#cek outlier
import seaborn as sns
sns.boxplot(y=df['Close'])
# Out:
# <Axes: ylabel='Close'>

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Clean and convert numeric columns to float (remove commas and handle non-numeric values)
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
for col in numeric_columns:
    # Convert column to string first, then remove commas
    df[col] = df[col].astype(str).str.replace(',', '', regex=True)
    # Convert to numeric, set errors to NaN for invalid values
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4937 non-null   datetime64[ns]
#  1   Open       4937 non-null   float64
#  2   High       4937 non-null   float64
#  3   Low        4937 non-null   float64
#  4   Close      4937 non-null   float64
#  5   Adj Close  4937 non-null   float64
#  6   Volume     4832 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 270.1 KB

# %%
df.isna().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume       105
# dtype: int64

# %%
df['Volume'].fillna(df['Volume'].mean(), inplace=True)

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           4937  4937.000000  4937.000000  4937.000000
# mean   2014-12-24 02:29:02.758760192  2538.934047  2568.830737  2505.757308
# min              2005-01-03 00:00:00   280.240000   282.700000   270.410000
# 25%              2009-12-29 00:00:00  1149.240000  1161.530000  1130.800000
# 50%              2015-01-12 00:00:00  2425.000000  2456.250000  2393.750000
# 75%              2019-11-25 00:00:00  3512.500000  3550.000000  3462.500000
# max              2024-12-30 00:00:00  7450.000000  7550.000000  7400.000000
# std                              NaN  1642.691574  1659.388604  1625.540178
#
#              Close    Adj Close        Volume
# count  4937.000000  4937.000000  4.937000e+03
# mean   2538.362820  1992.155289  1.274387e+08
# min     272.870000   144.060000  4.000000e+00
# 25%    1149.240000   695.840000  6.614510e+07
# 50%    2425.000000  1647.520000  9.767400e+07
# 75%    3500.000000  2756.970000  1.474136e+08
# max    7450.000000  7450.000000  1.899751e+09
# std    1642.070782  1637.221339  1.128514e+08

# %%
df.sort_values('Date', inplace=True, ignore_index=True)

df.head()
# Out:
#         Date    Open    High     Low   Close  Adj Close       Volume
# 0 2005-01-03  474.44  474.44  454.78  462.15     232.60   95398825.0
# 1 2005-01-04  462.15  491.65  462.15  491.65     247.44  380722734.0
# 2 2005-01-05  491.65  503.94  485.51  491.65     247.44  242069715.0
# 3 2005-01-06  485.51  503.94  485.51  503.94     253.63  158726170.0
# 4 2005-01-07  503.94  503.94  485.51  491.65     247.44  343273463.0

# %%
df = df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis='columns')
df
# Out:
#            Date    Close
# 0    2005-01-03   462.15
# 1    2005-01-04   491.65
# 2    2005-01-05   491.65
# 3    2005-01-06   503.94
# 4    2005-01-07   491.65
# ...         ...      ...
# 4932 2024-12-20  5675.00
# 4933 2024-12-23  5825.00
# 4934 2024-12-24  5750.00
# 4935 2024-12-27  5800.00
# 4936 2024-12-30  5700.00
#
# [4937 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
print("Starting date: ", df.iloc[0][0])
print("Ending date: ", df.iloc[-1][0])
print("Durasi: ", df.iloc[-1][0]-df.iloc[0][0])
# Out:
# Starting date:  2005-01-03 00:00:00
# Ending date:  2024-12-30 00:00:00
# Durasi:  7301 days 00:00:00

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='Date', y='Close')
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
train_unit = int(len(df) * 0.8)
test_unit = len(df) - train_unit
train_unit
# Out:
# 3949

# %%
train = df[:3949]
test= df[3949:]
train
# Out:
#            Date    Close
# 0    2005-01-03   462.15
# 1    2005-01-04   491.65
# 2    2005-01-05   491.65
# 3    2005-01-06   503.94
# 4    2005-01-07   491.65
# ...         ...      ...
# 3944 2020-11-24  3212.50
# 3945 2020-11-25  3262.50
# 3946 2020-11-26  3362.50
# 3947 2020-11-27  3325.00
# 3948 2020-11-30  3162.50
#
# [3949 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train = scaler.fit_transform(train[['Close']])
test = scaler.fit_transform(test[['Close']])
test
# Out:
# array([[0.09459459],
#        [0.10810811],
#        [0.1       ],
#        [0.1027027 ],
#        [0.11351351],
#        [0.11081081],
#        [0.12432432],
#        [0.12162162],
#        [0.11621622],
#        [0.11351351],
#        [0.12162162],
#        [0.13243243],
#        [0.11351351],
#        [0.11351351],
#        [0.08108108],
#        [0.07567568],
#        [0.09459459],
#        [0.08378378],
#        [0.07297297],
#        [0.09189189],
#        [0.08378378],
#        [0.08378378],
#        [0.08918919],
#        [0.0972973 ],
#        [0.12972973],
#        [0.14054054],
#        [0.13783784],
#        [0.12972973],
#        [0.11621622],
#        [0.13783784],
#        [0.14324324],
#        [0.18648649],
#        [0.17297297],
#        [0.16756757],
#        [0.17837838],
#        [0.18648649],
#        [0.17837838],
#        [0.15135135],
#        [0.1       ],
#        [0.11351351],
#        [0.08918919],
#        [0.09189189],
#        [0.1       ],
#        [0.0972973 ],
#        [0.1       ],
#        [0.09189189],
#        [0.09189189],
#        [0.09189189],
#        [0.09189189],
#        [0.08918919],
#        [0.07567568],
#        [0.06486486],
#        [0.07837838],
#        [0.07837838],
#        [0.07297297],
#        [0.07837838],
#        [0.06756757],
#        [0.05405405],
#        [0.1       ],
#        [0.1027027 ],
#        [0.1027027 ],
#        [0.0972973 ],
#        [0.08918919],
#        [0.08378378],
#        [0.08378378],
#        [0.09189189],
#        [0.11621622],
#        [0.10810811],
#        [0.0972973 ],
#        [0.09459459],
#        [0.12432432],
#        [0.12162162],
#        [0.10540541],
#        [0.11081081],
#        [0.08378378],
#        [0.08108108],
#        [0.08378378],
#        [0.07837838],
#        [0.07297297],
#        [0.05405405],
#        [0.05945946],
#        [0.06216216],
#        [0.06756757],
#        [0.07297297],
#        [0.06756757],
#        [0.08918919],
#        [0.07027027],
#        [0.07027027],
#        [0.07297297],
#        [0.07027027],
#        [0.07027027],
#        [0.06216216],
#        [0.05945946],
#        [0.05135135],
#        [0.05135135],
#        [0.05405405],
#        [0.03513514],
#        [0.04324324],
#        [0.05945946],
#        [0.06216216],
#        [0.05675676],
#        [0.04324324],
#        [0.04864865],
#        [0.04324324],
#        [0.04594595],
#        [0.03243243],
#        [0.03513514],
#        [0.02702703],
#        [0.02972973],
#        [0.02702703],
#        [0.0027027 ],
#        [0.        ],
#        [0.01891892],
#        [0.01081081],
#        [0.02702703],
#        [0.01081081],
#        [0.01621622],
#        [0.03783784],
#        [0.04864865],
#        [0.06486486],
#        [0.05135135],
#        [0.05135135],
#        [0.03783784],
#        [0.05405405],
#        [0.05945946],
#        [0.06756757],
#        [0.06756757],
#        [0.07297297],
#        [0.06756757],
#        [0.05945946],
#        [0.05945946],
#        [0.04054054],
#        [0.05675676],
#        [0.04054054],
#        [0.03513514],
#        [0.02702703],
#        [0.00540541],
#        [0.01351351],
#        [0.02702703],
#        [0.03513514],
#        [0.03243243],
#        [0.02162162],
#        [0.01351351],
#        [0.01081081],
#        [0.02702703],
#        [0.01351351],
#        [0.01621622],
#        [0.01351351],
#        [0.00540541],
#        [0.02432432],
#        [0.02432432],
#        [0.01081081],
#        [0.02972973],
#        [0.04324324],
#        [0.03513514],
#        [0.01621622],
#        [0.01891892],
#        [0.02702703],
#        [0.01081081],
#        [0.00540541],
#        [0.0027027 ],
#        [0.01351351],
#        [0.01891892],
#        [0.04324324],
#        [0.03513514],
#        [0.01621622],
#        [0.01621622],
#        [0.02972973],
#        [0.03783784],
#        [0.03513514],
#        [0.04324324],
#        [0.02162162],
#        [0.02702703],
#        [0.03513514],
#        [0.01891892],
#        [0.03243243],
#        [0.01891892],
#        [0.01621622],
#        [0.03243243],
#        [0.04864865],
#        [0.03783784],
#        [0.04324324],
#        [0.05135135],
#        [0.05945946],
#        [0.06486486],
#        [0.06486486],
#        [0.07567568],
#        [0.05945946],
#        [0.05405405],
#        [0.04864865],
#        [0.05135135],
#        [0.05405405],
#        [0.04324324],
#        [0.04054054],
#        [0.03513514],
#        [0.04594595],
#        [0.04594595],
#        [0.03513514],
#        [0.02702703],
#        [0.03243243],
#        [0.03783784],
#        [0.05405405],
#        [0.04864865],
#        [0.08918919],
#        [0.08378378],
#        [0.1027027 ],
#        [0.11351351],
#        [0.13513514],
#        [0.13513514],
#        [0.14594595],
#        [0.15675676],
#        [0.16486486],
#        [0.16216216],
#        [0.16486486],
#        [0.16756757],
#        [0.16486486],
#        [0.16756757],
#        [0.15945946],
#        [0.16486486],
#        [0.16216216],
#        [0.14864865],
#        [0.16486486],
#        [0.16486486],
#        [0.14864865],
#        [0.15945946],
#        [0.16486486],
#        [0.15675676],
#        [0.14594595],
#        [0.13243243],
#        [0.16216216],
#        [0.17027027],
#        [0.15675676],
#        [0.15135135],
#        [0.17027027],
#        [0.17027027],
#        [0.16486486],
#        [0.17297297],
#        [0.18378378],
#        [0.16216216],
#        [0.16216216],
#        [0.18378378],
#        [0.15675676],
#        [0.16486486],
#        [0.14594595],
#        [0.15405405],
#        [0.16756757],
#        [0.16216216],
#        [0.16486486],
#        [0.17837838],
#        [0.16216216],
#        [0.18378378],
#        [0.16756757],
#        [0.15945946],
#        [0.16486486],
#        [0.17567568],
#        [0.17297297],
#        [0.16216216],
#        [0.15405405],
#        [0.16216216],
#        [0.15135135],
#        [0.15405405],
#        [0.15135135],
#        [0.14594595],
#        [0.15135135],
#        [0.15675676],
#        [0.14864865],
#        [0.15135135],
#        [0.16486486],
#        [0.14864865],
#        [0.14864865],
#        [0.15135135],
#        [0.15135135],
#        [0.15135135],
#        [0.16216216],
#        [0.15945946],
#        [0.16486486],
#        [0.16756757],
#        [0.17297297],
#        [0.14864865],
#        [0.16486486],
#        [0.17837838],
#        [0.17567568],
#        [0.17027027],
#        [0.1972973 ],
#        [0.20540541],
#        [0.21621622],
#        [0.1972973 ],
#        [0.1972973 ],
#        [0.1972973 ],
#        [0.1972973 ],
#        [0.2       ],
#        [0.21351351],
#        [0.21891892],
#        [0.22432432],
#        [0.22432432],
#        [0.23243243],
#        [0.24324324],
#        [0.23783784],
#        [0.23783784],
#        [0.23783784],
#        [0.23783784],
#        [0.24054054],
#        [0.24054054],
#        [0.22162162],
#        [0.22162162],
#        [0.21621622],
#        [0.21351351],
#        [0.21621622],
#        [0.20540541],
#        [0.20540541],
#        [0.21351351],
#        [0.21891892],
#        [0.21621622],
#        [0.22702703],
#        [0.22972973],
#        [0.24864865],
#        [0.24864865],
#        [0.24594595],
#        [0.21621622],
#        [0.21891892],
#        [0.22972973],
#        [0.24594595],
#        [0.23783784],
#        [0.24054054],
#        [0.24594595],
#        [0.24054054],
#        [0.24324324],
#        [0.24054054],
#        [0.23513514],
#        [0.23513514],
#        [0.21891892],
#        [0.22162162],
#        [0.22162162],
#        [0.21891892],
#        [0.22162162],
#        [0.22432432],
#        [0.21891892],
#        [0.21351351],
#        [0.20810811],
#        [0.59459459],
#        [0.60540541],
#        [0.62162162],
#        [0.62702703],
#        [0.61081081],
#        [0.62162162],
#        [0.64324324],
#        [0.63783784],
#        [0.65945946],
#        [0.66486486],
#        [0.66486486],
#        [0.68108108],
#        [0.67027027],
#        [0.67567568],
#        [0.64324324],
#        [0.64324324],
#        [0.63783784],
#        [0.64864865],
#        [0.67567568],
#        [0.65405405],
#        [0.67567568],
#        [0.66486486],
#        [0.68648649],
#        [0.67567568],
#        [0.68108108],
#        [0.69189189],
#        [0.7027027 ],
#        [0.70810811],
#        [0.70810811],
#        [0.6972973 ],
#        [0.65945946],
#        [0.66486486],
#        [0.67027027],
#        [0.65945946],
#        [0.65405405],
#        [0.64864865],
#        [0.67027027],
#        [0.66486486],
#        [0.68648649],
#        [0.7027027 ],
#        [0.68648649],
#        [0.68648649],
#        [0.68648649],
#        [0.67027027],
#        [0.68648649],
#        [0.69189189],
#        [0.6972973 ],
#        [0.7027027 ],
#        [0.71351351],
#        [0.71351351],
#        [0.69189189],
#        [0.66486486],
#        [0.68648649],
#        [0.6972973 ],
#        [0.7027027 ],
#        [0.7027027 ],
#        [0.69189189],
#        [0.68648649],
#        [0.65405405],
#        [0.62702703],
#        [0.63243243],
#        [0.61621622],
#        [0.63243243],
#        [0.65405405],
#        [0.62162162],
#        [0.62162162],
#        [0.62702703],
#        [0.61621622],
#        [0.61081081],
#        [0.66486486],
#        [0.64864865],
#        [0.67027027],
#        [0.65945946],
#        [0.65405405],
#        [0.65945946],
#        [0.63783784],
#        [0.64864865],
#        [0.64864865],
#        [0.67027027],
#        [0.67027027],
#        [0.66486486],
#        [0.65945946],
#        [0.65945946],
#        [0.65945946],
#        [0.66486486],
#        [0.65945946],
#        [0.66486486],
#        [0.66486486],
#        [0.65405405],
#        [0.65405405],
#        [0.66486486],
#        [0.68648649],
#        [0.68108108],
#        [0.64324324],
#        [0.63243243],
#        [0.62162162],
#        [0.63783784],
#        [0.64324324],
#        [0.62702703],
#        [0.67567568],
#        [0.66486486],
#        [0.67027027],
#        [0.68108108],
#        [0.67027027],
#        [0.68108108],
#        [0.68108108],
#        [0.68648649],
#        [0.71351351],
#        [0.6972973 ],
#        [0.71351351],
#        [0.70810811],
#        [0.76216216],
#        [0.77837838],
#        [0.77297297],
#        [0.76756757],
#        [0.77837838],
#        [0.78378378],
#        [0.81081081],
#        [0.79459459],
#        [0.8       ],
#        [0.8       ],
#        [0.8       ],
#        [0.8       ],
#        [0.79459459],
#        [0.79459459],
#        [0.77297297],
#        [0.74594595],
#        [0.75135135],
#        [0.78918919],
#        [0.82702703],
#        [0.82702703],
#        [0.80540541],
#        [0.83243243],
#        [0.86486486],
#        [0.87027027],
#        [0.89189189],
#        [0.92432432],
#        [0.90810811],
#        [0.94594595],
#        [0.94594595],
#        [0.93513514],
#        [0.93513514],
#        [0.95675676],
#        [0.92432432],
#        [0.91351351],
#        [0.91351351],
#        [0.91891892],
#        [0.92972973],
#        [0.9027027 ],
#        [0.90810811],
#        [0.90810811],
#        [0.90810811],
#        [0.91891892],
#        [0.92432432],
#        [0.92972973],
#        [0.96216216],
#        [0.98918919],
#        [0.98918919],
#        [0.94054054],
#        [0.96216216],
#        [0.91351351],
#        [0.91351351],
#        [0.91351351],
#        [0.95675676],
#        [0.94054054],
#        [0.94054054],
#        [0.95675676],
#        [0.88108108],
#        [0.88108108],
#        [0.85405405],
#        [0.87567568],
#        [0.86486486],
#        [0.82162162],
#        [0.82162162],
#        [0.85945946],
#        [0.84324324],
#        [0.84324324],
#        [0.86486486],
#        [0.91351351],
#        [0.89189189],
#        [0.84864865],
#        [0.88648649],
#        [0.88108108],
#        [0.75675676],
#        [0.71891892],
#        [0.74594595],
#        [0.74594595],
#        [0.74594595],
#        [0.72972973],
#        [0.72972973],
#        [0.76756757],
#        [0.76216216],
#        [0.81081081],
#        [0.75675676],
#        [0.69189189],
#        [0.6972973 ],
#        [0.64864865],
#        [0.67567568],
#        [0.64324324],
#        [0.65945946],
#        [0.66486486],
#        [0.70810811],
#        [0.71891892],
#        [0.68648649],
#        [0.72432432],
#        [0.74594595],
#        [0.74594595],
#        [0.71351351],
#        [0.67027027],
#        [0.65945946],
#        [0.63243243],
#        [0.63243243],
#        [0.67567568],
#        [0.71351351],
#        [0.68648649],
#        [0.67027027],
#        [0.65405405],
#        [0.68648649],
#        [0.71891892],
#        [0.74054054],
#        [0.72972973],
#        [0.73513514],
#        [0.74054054],
#        [0.77837838],
#        [0.73513514],
#        [0.76756757],
#        [0.76756757],
#        [0.77297297],
#        [0.77837838],
#        [0.76216216],
#        [0.76216216],
#        [0.78378378],
#        [0.80540541],
#        [0.8       ],
#        [0.83783784],
#        [0.82162162],
#        [0.78918919],
#        [0.81081081],
#        [0.80540541],
#        [0.78918919],
#        [0.78918919],
#        [0.77297297],
#        [0.84864865],
#        [0.85945946],
#        [0.81081081],
#        [0.82162162],
#        [0.85405405],
#        [0.85945946],
#        [0.87027027],
#        [0.88108108],
#        [0.9027027 ],
#        [0.91891892],
#        [0.90810811],
#        [0.91891892],
#        [0.93513514],
#        [0.94594595],
#        [0.95675676],
#        [0.91351351],
#        [0.91351351],
#        [0.91351351],
#        [0.90810811],
#        [0.95135135],
#        [0.92432432],
#        [0.92972973],
#        [0.94594595],
#        [0.91891892],
#        [0.94054054],
#        [0.94054054],
#        [0.95675676],
#        [0.95675676],
#        [0.95675676],
#        [0.98378378],
#        [0.96756757],
#        [0.96216216],
#        [0.99459459],
#        [0.98918919],
#        [0.98918919],
#        [0.96756757],
#        [1.        ],
#        [0.99459459],
#        [0.94594595],
#        [0.94054054],
#        [0.91351351],
#        [0.88648649],
#        [0.91351351],
#        [0.8972973 ],
#        [0.91351351],
#        [0.89189189],
#        [0.87567568],
#        [0.91891892],
#        [0.89189189],
#        [0.89189189],
#        [0.89189189],
#        [0.88648649],
#        [0.91351351],
#        [0.9027027 ],
#        [0.95135135],
#        [0.94054054],
#        [0.94594595],
#        [0.91891892],
#        [0.91891892],
#        [0.8972973 ],
#        [0.91351351],
#        [0.86486486],
#        [0.86486486],
#        [0.84864865],
#        [0.83783784],
#        [0.82702703],
#        [0.84864865],
#        [0.88648649],
#        [0.80540541],
#        [0.77837838],
#        [0.75675676],
#        [0.76216216],
#        [0.76756757],
#        [0.77837838],
#        [0.76756757],
#        [0.76216216],
#        [0.75675676],
#        [0.74054054],
#        [0.73513514],
#        [0.71891892],
#        [0.74054054],
#        [0.81081081],
#        [0.77297297],
#        [0.78378378],
#        [0.71891892],
#        [0.68648649],
#        [0.74594595],
#        [0.76756757],
#        [0.71891892],
#        [0.73513514],
#        [0.76756757],
#        [0.75135135],
#        [0.75135135],
#        [0.71351351],
#        [0.69189189],
#        [0.7027027 ],
#        [0.67567568],
#        [0.64864865],
#        [0.61621622],
#        [0.61621622],
#        [0.64864865],
#        [0.63243243],
#        [0.64324324],
#        [0.62162162]])

# %%
# %pip install statsmodels

# %%
# df.isna().sum()

# %%
# #cek data stationer atau tidak 
# from statsmodels.tsa.stattools import adfuller
# def adfuller_test(close):
#   result=adfuller(close)
#   labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
#   for value,label in zip(result,labels):
#     print(label+' : '+str(value) )
#   if result[1] <= 0.05:
#     print("strong evidence against the null hypothesis(Ho), Data is stationary")
#   else:
#     print("weak evidence against null hypothesis, indicating it is non- stationary ")
# adfuller_test(df['Close'])

# %%
# # Differencing pada kolom Close
# df['Close_diff'] = df['Close'].diff()

# print("Data setelah differencing:")
# print(df)

# %%
# # Mengganti NaN dengan mean dari kolom Close_diff
# mean_close_diff = df['Close_diff'].mean()
# df['Close_diff'].fillna(mean_close_diff, inplace=True)

# print("Data setelah differencing dan mengganti NaN dengan mean:")
# print(df)

# %%
# adfuller_test(df['Close_diff'])

# %%
# Menghitung rata-rata bergerak
window_size = 30
df['asli_Close'] = df['Close'].rolling(window=window_size).mean()

# Plot data asli dan rata-rata bergerak
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Data Asli (Close)')
plt.plot(df['Date'], df['asli_Close'], label=f'Rata-Rata Bergerak ({window_size} periode)', color='red')

plt.title('Plot Data Close dengan Rata-Rata Bergerak')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Close')
plt.legend()
plt.show()

# %%
def sliding_window(data, window_size):
    sub_seq, next_values = [], []
    for i in range(len(data) - window_size):
        sub_seq.append(data[i:i+window_size])
        next_values.append(data[i+window_size])
    x = np.stack(sub_seq)
    y = np.array(next_values)
    return x, y

window_size = 30
X_train, y_train = sliding_window(train, window_size)
X_test, y_test = sliding_window(test, window_size)

# Reshape X_train dan X_test untuk menambahkan dimensi fitur
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3919, 30, 1) (3919, 1)
# (958, 30, 1) (958, 1)

# %%
# Membuat model LSTM
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()    
model.add(LSTM(50, input_shape=(window_size, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])

# Melatih model
history = model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# Prediksi menggunakan data pengujian
testPredict = model.predict(test)
# Out:
# Epoch 1/100
# 3919/3919 - 17s - 4ms/step - loss: 0.0012 - mae: 0.0189
# Epoch 2/100
# 3919/3919 - 15s - 4ms/step - loss: 3.2035e-04 - mae: 0.0130
# Epoch 3/100
# 3919/3919 - 15s - 4ms/step - loss: 2.2189e-04 - mae: 0.0106
# Epoch 4/100
# 3919/3919 - 15s - 4ms/step - loss: 1.8590e-04 - mae: 0.0098
# Epoch 5/100
# 3919/3919 - 15s - 4ms/step - loss: 1.8380e-04 - mae: 0.0097
# Epoch 6/100
# 3919/3919 - 15s - 4ms/step - loss: 1.7875e-04 - mae: 0.0096
# Epoch 7/100
# 3919/3919 - 15s - 4ms/step - loss: 1.7558e-04 - mae: 0.0094
# Epoch 8/100
# 3919/3919 - 15s - 4ms/step - loss: 1.7404e-04 - mae: 0.0093
# Epoch 9/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6818e-04 - mae: 0.0092
# Epoch 10/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6584e-04 - mae: 0.0091
# Epoch 11/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6377e-04 - mae: 0.0091
# Epoch 12/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6162e-04 - mae: 0.0091
# Epoch 13/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6517e-04 - mae: 0.0091
# Epoch 14/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6254e-04 - mae: 0.0090
# Epoch 15/100
# 3919/3919 - 15s - 4ms/step - loss: 1.6170e-04 - mae: 0.0091
# Epoch 16/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5247e-04 - mae: 0.0087
# Epoch 17/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5567e-04 - mae: 0.0088
# Epoch 18/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5799e-04 - mae: 0.0089
# Epoch 19/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5485e-04 - mae: 0.0088
# Epoch 20/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5304e-04 - mae: 0.0087
# Epoch 21/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4820e-04 - mae: 0.0085
# Epoch 22/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4749e-04 - mae: 0.0084
# Epoch 23/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4668e-04 - mae: 0.0085
# Epoch 24/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4893e-04 - mae: 0.0085
# Epoch 25/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5052e-04 - mae: 0.0085
# Epoch 26/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4727e-04 - mae: 0.0085
# Epoch 27/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4936e-04 - mae: 0.0086
# Epoch 28/100
# 3919/3919 - 15s - 4ms/step - loss: 1.5211e-04 - mae: 0.0086
# Epoch 29/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4798e-04 - mae: 0.0086
# Epoch 30/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4337e-04 - mae: 0.0084
# Epoch 31/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4249e-04 - mae: 0.0083
# Epoch 32/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4296e-04 - mae: 0.0083
# Epoch 33/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4256e-04 - mae: 0.0083
# Epoch 34/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4745e-04 - mae: 0.0085
# Epoch 35/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4099e-04 - mae: 0.0083
# Epoch 36/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4535e-04 - mae: 0.0084
# Epoch 37/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4651e-04 - mae: 0.0084
# Epoch 38/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4424e-04 - mae: 0.0084
# Epoch 39/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4298e-04 - mae: 0.0083
# Epoch 40/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4233e-04 - mae: 0.0083
# Epoch 41/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4168e-04 - mae: 0.0083
# Epoch 42/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3957e-04 - mae: 0.0082
# Epoch 43/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4090e-04 - mae: 0.0082
# Epoch 44/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4120e-04 - mae: 0.0083
# Epoch 45/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4088e-04 - mae: 0.0083
# Epoch 46/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3968e-04 - mae: 0.0082
# Epoch 47/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3937e-04 - mae: 0.0082
# Epoch 48/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4040e-04 - mae: 0.0083
# Epoch 49/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4023e-04 - mae: 0.0083
# Epoch 50/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3883e-04 - mae: 0.0082
# Epoch 51/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3955e-04 - mae: 0.0083
# Epoch 52/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4108e-04 - mae: 0.0083
# Epoch 53/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4013e-04 - mae: 0.0082
# Epoch 54/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3608e-04 - mae: 0.0082
# Epoch 55/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3650e-04 - mae: 0.0081
# Epoch 56/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3626e-04 - mae: 0.0081
# Epoch 57/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3978e-04 - mae: 0.0082
# Epoch 58/100
# 3919/3919 - 15s - 4ms/step - loss: 1.4041e-04 - mae: 0.0082
# Epoch 59/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3999e-04 - mae: 0.0082
# Epoch 60/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3841e-04 - mae: 0.0082
# Epoch 61/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3687e-04 - mae: 0.0081
# Epoch 62/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3580e-04 - mae: 0.0081
# Epoch 63/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3762e-04 - mae: 0.0082
# Epoch 64/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3724e-04 - mae: 0.0081
# Epoch 65/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3645e-04 - mae: 0.0081
# Epoch 66/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3746e-04 - mae: 0.0081
# Epoch 67/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3615e-04 - mae: 0.0081
# Epoch 68/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3399e-04 - mae: 0.0080
# Epoch 69/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3723e-04 - mae: 0.0081
# Epoch 70/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3922e-04 - mae: 0.0082
# Epoch 71/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3851e-04 - mae: 0.0082
# Epoch 72/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3769e-04 - mae: 0.0081
# Epoch 73/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3717e-04 - mae: 0.0082
# Epoch 74/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3678e-04 - mae: 0.0081
# Epoch 75/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3833e-04 - mae: 0.0082
# Epoch 76/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3611e-04 - mae: 0.0081
# Epoch 77/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3725e-04 - mae: 0.0081
# Epoch 78/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3832e-04 - mae: 0.0083
# Epoch 79/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3545e-04 - mae: 0.0081
# Epoch 80/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3491e-04 - mae: 0.0081
# Epoch 81/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3619e-04 - mae: 0.0081
# Epoch 82/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3568e-04 - mae: 0.0081
# Epoch 83/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3603e-04 - mae: 0.0080
# Epoch 84/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3576e-04 - mae: 0.0081
# Epoch 85/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3498e-04 - mae: 0.0081
# Epoch 86/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3555e-04 - mae: 0.0081
# Epoch 87/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3241e-04 - mae: 0.0080
# Epoch 88/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3579e-04 - mae: 0.0081
# Epoch 89/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3569e-04 - mae: 0.0081
# Epoch 90/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3345e-04 - mae: 0.0080
# Epoch 91/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3530e-04 - mae: 0.0081
# Epoch 92/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3406e-04 - mae: 0.0080
# Epoch 93/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3331e-04 - mae: 0.0080
# Epoch 94/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3605e-04 - mae: 0.0080
# Epoch 95/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3556e-04 - mae: 0.0080
# Epoch 96/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3528e-04 - mae: 0.0081
# Epoch 97/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3511e-04 - mae: 0.0081
# Epoch 98/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3339e-04 - mae: 0.0080
# Epoch 99/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3450e-04 - mae: 0.0080
# Epoch 100/100
# 3919/3919 - 15s - 4ms/step - loss: 1.3332e-04 - mae: 0.0079
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
import matplotlib.pyplot as plt

# Plot loss dan MAE selama pelatihan
plt.figure(figsize=(12, 6))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.title('Loss selama Pelatihan')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='MAE', color='orange')
plt.title('MAE selama Pelatihan')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import r2_score


mae_test = metrics.mean_absolute_error(test, testPredict)
mse_test = metrics.mean_squared_error(test, testPredict)
rmse_test = np.sqrt(mse_test)
r2 = r2_score(test, testPredict)


print("Hasil MAE Test : ", mae_test)
print("Hasil MSE Test : ", mse_test)
print("Hasil RMSE Test : ", rmse_test)
print("Hasil R2 Test : ", r2)
# Out:
# Hasil MAE Test :  0.0088734397745906
# Hasil MSE Test :  0.000102418212181773
# Hasil RMSE Test :  0.010120188347149128
# Hasil R2 Test :  0.9988020167162658

# %%
# Asumsikan Anda memiliki DataFrame `df` yang berisi kolom 'Date' dan 'Close'
# dan `testPredict` adalah hasil prediksi dari model LSTM Anda.

# Plotting hasil prediksi vs data aktual
plt.figure(figsize=(15, 7))
plt.plot(df['Date'].iloc[-len(test):], test, label='Actual Close Price')
plt.plot(df['Date'].iloc[-len(test):], testPredict, label='Predicted Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Actual vs Predicted Close Price')
plt.legend()
plt.show()

# %%
# Inverse transform y_test to get the original values
true_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Prediksi 7 hari ke depan
# Kita perlu menggunakan data terakhir dari test set sebagai input untuk prediksi
last_sequence = test[-1].reshape(1, -1)  # Ambil sequence terakhir dari test set
predict_next_7_days = []

for _ in range(7):
    next_pred = model.predict(last_sequence)
    predict_next_7_days.append(next_pred[0][0])
    # Update last_sequence dengan prediksi terbaru
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[0, -1] = next_pred

# Inverse transform prediksi ke skala asli
predict_next_7_days_original = scaler.inverse_transform(np.array(predict_next_7_days).reshape(-1, 1))

# Tanggal untuk data test
test_dates = df['Date'][-len(y_test):].reset_index(drop=True)

# Tanggal untuk prediksi 7 hari ke depan
last_date = test_dates.iloc[-1]
prediction_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=7, freq='D')

# Plotting hasil prediksi
plt.figure(figsize=(15, 7))

# Plot data asli (test data)
plt.plot(test_dates, true_test, label='Data Asli (Test)', color='blue')

# Plot prediksi 7 hari ke depan
# Tambahkan titik terakhir dari data asli ke awal prediksi untuk menghubungkan garis
plt.plot([test_dates.iloc[-1]] + prediction_dates.tolist(), 
         [true_test[-1][0]] + predict_next_7_days_original.flatten().tolist(), 
         label='Prediksi 7 Hari ke Depan', color='green')

# Menambahkan judul dan label
plt.title('Prediksi 7 Hari ke Depan')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)  # Rotasi tanggal agar tidak bertumpuk
plt.tight_layout()  # Agar layout tidak terpotong
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
# Membuat DataFrame untuk prediksi 7 hari ke depan
future_predictions = pd.DataFrame({
    'Date': prediction_dates,
    'Predict': predict_next_7_days_original.flatten()
})

# Menampilkan tabel prediksi 7 hari ke depan
print("Prediksi 7 Hari ke Depan:")
print(future_predictions)
# Out:
# Prediksi 7 Hari ke Depan:
#         Date      Predict
# 0 2024-12-31  5670.711426
# 1 2025-01-01  5640.706543
# 2 2025-01-02  5609.929688
# 3 2025-01-03  5578.322754
# 4 2025-01-04  5545.828613
# 5 2025-01-05  5512.387695
# 6 2025-01-06  5477.940918

# %%
from tensorflow.keras.models import save_model
save_model(model, 'lstm_model.h5')  # Simpan model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
